# %% [markdown]
# Лабораторная работа 7.
# Использование разработанного пайплайна для многомерной регрессии

# %%
# Подключение библиотек

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
  
# Загрузка данных и разделение на матрицу признаков и зависимую переменную

dataset = pd.read_csv('../MMO/Datasets/social_network_ads_lab7.csv')
dataset.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            76000
# 2   26            43000
# 3   53            57000
# 4   19            54000

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
print ("Матрица признаков"); print(X[:5])
print ("Зависимая переменная"); print(y[:5])
# Out:
# Матрица признаков
# [[19]
#  [35]
#  [26]
#  [53]
#  [19]]
# Зависимая переменная
# [19000 76000 43000 57000 54000]

# %%
# Разделение выборки на тестовую и тренировочную

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/4, random_state = 0)

# %%
# Обучение линейной модели регрессии

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Обработка результатов, тюнинг модели

# Предсказание

y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [56757.54405195 59559.44729543 59559.44729543 53021.67306063
#  59559.44729543 39946.12459104 59559.44729543 58625.47954761
#  39012.15684321 66097.22153023 57691.51179978 51153.73756498
#  38078.18909538]

# %%
# Оптимизация модели

import statsmodels.api as sm
X = np.append(arr = np.ones((50, 1)).astype(int), values = X, axis = 1)
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 11 Dec 2022   Prob (F-statistic):                nan
# Time:                        23:49:09   Log-Likelihood:                -591.69
# No. Observations:                  50   AIC:                             1185.
# Df Residuals:                      49   BIC:                             1187.
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8870.0000    794.044     11.171      0.000    7274.309    1.05e+04
# x1          8870.0000    794.044     11.171      0.000    7274.309    1.05e+04
# x2          8870.0000    794.044     11.171      0.000    7274.309    1.05e+04
# x3          8870.0000    794.044     11.171      0.000    7274.309    1.05e+04
# x4          8870.0000    794.044     11.171      0.000    7274.309    1.05e+04
# x5          8870.0000    794.044     11.171      0.000    7274.309    1.05e+04
# ==============================================================================
# Omnibus:                        9.734   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.363
# Skew:                           1.024   Prob(JB):                      0.00926
# Kurtosis:                       3.545   Cond. No.                     8.22e+80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.44e-160. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:, [0, 1, 3, 4, 5]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 11 Dec 2022   Prob (F-statistic):                nan
# Time:                        23:50:24   Log-Likelihood:                -591.69
# No. Observations:                  50   AIC:                             1185.
# Df Residuals:                      49   BIC:                             1187.
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.064e+04    952.852     11.171      0.000    8729.171    1.26e+04
# x1          1.064e+04    952.852     11.171      0.000    8729.171    1.26e+04
# x2          1.064e+04    952.852     11.171      0.000    8729.171    1.26e+04
# x3          1.064e+04    952.852     11.171      0.000    8729.171    1.26e+04
# x4          1.064e+04    952.852     11.171      0.000    8729.171    1.26e+04
# ==============================================================================
# Omnibus:                        9.734   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.363
# Skew:                           1.024   Prob(JB):                      0.00926
# Kurtosis:                       3.545   Cond. No.                     3.74e+48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.78e-95. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:, [0, 3, 4, 5]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 11 Dec 2022   Prob (F-statistic):                nan
# Time:                        23:50:35   Log-Likelihood:                -591.69
# No. Observations:                  50   AIC:                             1185.
# Df Residuals:                      49   BIC:                             1187.
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.331e+04   1191.066     11.171      0.000    1.09e+04    1.57e+04
# x1          1.331e+04   1191.066     11.171      0.000    1.09e+04    1.57e+04
# x2          1.331e+04   1191.066     11.171      0.000    1.09e+04    1.57e+04
# x3          1.331e+04   1191.066     11.171      0.000    1.09e+04    1.57e+04
# ==============================================================================
# Omnibus:                        9.734   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.363
# Skew:                           1.024   Prob(JB):                      0.00926
# Kurtosis:                       3.545   Cond. No.                     2.50e+47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.19e-93. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:, [0, 3, 5]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 11 Dec 2022   Prob (F-statistic):                nan
# Time:                        23:50:44   Log-Likelihood:                -591.69
# No. Observations:                  50   AIC:                             1185.
# Df Residuals:                      49   BIC:                             1187.
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.774e+04   1588.087     11.171      0.000    1.45e+04    2.09e+04
# x1          1.774e+04   1588.087     11.171      0.000    1.45e+04    2.09e+04
# x2          1.774e+04   1588.087     11.171      0.000    1.45e+04    2.09e+04
# ==============================================================================
# Omnibus:                        9.734   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.363
# Skew:                           1.024   Prob(JB):                      0.00926
# Kurtosis:                       3.545   Cond. No.                     1.47e+32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.93e-63. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt = X[:, [0, 3]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 11 Dec 2022   Prob (F-statistic):                nan
# Time:                        23:50:52   Log-Likelihood:                -591.69
# No. Observations:                  50   AIC:                             1185.
# Df Residuals:                      49   BIC:                             1187.
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.661e+04   2382.131     11.171      0.000    2.18e+04    3.14e+04
# x1          2.661e+04   2382.131     11.171      0.000    2.18e+04    3.14e+04
# ==============================================================================
# Omnibus:                        9.734   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.363
# Skew:                           1.024   Prob(JB):                      0.00926
# Kurtosis:                       3.545   Cond. No.                     5.02e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.98e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
